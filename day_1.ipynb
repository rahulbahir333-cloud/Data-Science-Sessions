# %%
p=1000
d=0.2
fp=p-(p*d)
print("FINAL PRICE AFTER DISCOUNT:",fp)
# Out:
# FINAL PRICE AFTER DISCOUNT: 800.0

# %%
p=1000
d=0.2
fp=p-(p*d)
tax=fp*0.12
add=tax+fp
print("FINAL PRICE AFTER DISCOUNT:",fp)
print(f"CUSTOMER NEEDS TO PAY {add} after discount and tax")
# Out:
# FINAL PRICE AFTER DISCOUNT: 800.0
# CUSTOMER NEEDS TO PAY 896.0 after discount and tax

# %%
customer_n="PRACHI_19"
age=19
salary=55000.75
print(type(customer_n))
print(type(age))
print(type(salary))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
marks=int(input("Enter the score:"))
if marks>95:
    print("GRADE: A+(OUTSTANDING)")
elif marks>90:
    print("GRADE: A(Excellent)")
elif marks>75:
  print("GRADE: B(Good)")
elif marks>60:
  print("GRADE: C(NEEDS IMPROVEMENT)")
else:
  print("GRADE: D(FAIL)")
# Out:
# Enter the score:78
# GRADE: B(Good)

# %%
customers=["PRACHI","GOURI","ASMITA","PRIYAL","DIVYA",25]
for name in customers:
  print("SENDING EMAIL TO:",name)
# Out:
# SENDING EMAIL TO: PRACHI
# SENDING EMAIL TO: GOURI
# SENDING EMAIL TO: ASMITA
# SENDING EMAIL TO: PRIYAL
# SENDING EMAIL TO: DIVYA
# SENDING EMAIL TO: 25

# %%
student={"PRACHI":85,"GOURI":92,"DIVYA":74}
for name, marks in student.items():
  if marks > 90:
    grade="A"
  elif marks >=75:
    grade="B"
  else:
    grade="C"
  print(f"STUDENT:{name},MARKS:{marks},GRADE:{grade}")
# Out:
# STUDENT:PRACHI,MARKS:85,GRADE:B
# STUDENT:GOURI,MARKS:92,GRADE:A
# STUDENT:DIVYA,MARKS:74,GRADE:C

# %%
def greet(name):
  print("HELLO", name,"WELCOME TO THE BOOTCAMP!!")
greet("PRACH")
greet("DIVYAA")
# Out:
# HELLO PRACH WELCOME TO THE BOOTCAMP!!
# HELLO DIVYAA WELCOME TO THE BOOTCAMP!!

# %%
def Money(x,y):
  total=x+y
  return total
Money(1000,2000)
Money("abc","xyz")
# Out:
# 'abcxyz'

# %%
def eligibility(age):
  print(age)
  if age>=18:
    print("ELIGIBLE FOR VOTING")
  else:
    print("NOT ELIGIBLE FOR VOTING")
eligibility(19)
eligibility(17)
# Out:
# 19
# ELIGIBLE FOR VOTING
# 17
# NOT ELIGIBLE FOR VOTING

# %%
#hw
def calculate_discount(price, discount_percent):
  return price - (price * discount_percent / 100)
def apply_tax(price, tax_percent):
 return price + (price * tax_percent / 100)
price = 1000
discounted_price = calculate_discount (price, 10)
final_price = apply_tax(discounted_price, 18)
print ("Final Price after discount and tax:", final_price)
# Out:
# Final Price after discount and tax: 1062.0

# %%
import math
print("SQUARE ROOT OF 25:",math.sqrt(25))
print("VALUE OF PI:",math.pi)
# Out:
# SQUARE ROOT OF 25: 5.0
# VALUE OF PI: 3.141592653589793

# %%
def issue_books(student_name, books):
  print (f"\n (student_name) borrowed: ")
  for book in books:
   print ("-", book)
def calculate_fine(days_late):
 fine_per_day = 5
 return days_late*fine_per_day
def student_report(student_name, books, days_late):
 issue_books(student_name, books)
 fine=calculate_fine(days_late)
 print(f"Fine to be paid:{fine}\n")
student_report("Rahul", ["Python Basics", "Data Science 101"], 3)
student_report("Priya", ["MACHINE LEARNING"], 0)
# Out:
#  (student_name) borrowed:
# - Python Basics
# - Data Science 101
# Fine to be paid:15
#
#
#  (student_name) borrowed:
# - MACHINE LEARNING
# Fine to be paid:0
